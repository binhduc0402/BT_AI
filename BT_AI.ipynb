# %% [markdown]
# <a href="https://colab.research.google.com/github/binhduc0402/BT_AI/blob/main/BT_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('text.txt',mode='w') as account:
  account.write('20146 A 9\n')
  account.write('20146 B 10\n')
  account.write('20146 C 8\n')

# %%
with open('text.txt',mode='r') as account:
  print(f"{'MSSV':<10}{'name':<20}{'score':>2}")
  for record in account:
    MSSV,name,score=record.split()
    print(f"{'MSSV':<10}{'name':<20}{'score':>2}")
# Out:
# MSSV      name                score
# MSSV      name                score
# MSSV      name                score
# MSSV      name                score

# %%
import pandas as pd
url='data2.csv'
dataframe=pd.read_csv(url)
dataframe.head(22)
dataframe.iloc[5:10]
data=dataframe.set_index(dataframe['Ho va ten'])
data.loc['A']
dataframe[dataframe['Diem']==6].head(3)
dataframe[(dataframe['Khoa']=='CNTT')&(dataframe['Diem']==6)] #Hien len thong tin khoa cntt diem=6
dataframe['Khoa'].replace('CNTT','cong nghe tt').head(21) #thay the cntt ->cong nghe tt
print('Diem cao nhat',dataframe['Diem'].min()) #in diem thap nhat
dataframe['Khoa'].unique()            #liet ke khoa gom nhung cai gi
dataframe['Khoa'].value_counts()      #Dem so 
dataframe.drop('STT',axis=1).head(10) #Xoa 1 cot du lieu
dataframe.drop(dataframe.columns[2:4],axis=1).head(21)#xoa cot 2 va 4 (bat dau tu 0)
dataframe[dataframe['Khoa']!='CKM'].head(21) #xoa hang CKM
dataframe.drop_duplicates().head(21) #nhom cac gia tri giong nhau
#dataframe.groupby(['Khoa','diem']).count()
dataframe.info()
# Out:
# Diem cao nhat 0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STT        21 non-null     int64
#  1   MSSV       21 non-null     int64
#  2   Ho va ten  21 non-null     object
#  3   Khoa       21 non-null     object
#  4   Diem       21 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 968.0+ bytes

# %%
import pandas as pd
import numpy as np
time_index=pd.date_range('01/01/2023',periods=100000,freq='30s')
dataframe=pd.DataFrame(index=time_index)
dataframe['Acess_Account']=np.random.randint(1,10,100000)
dataframe.resample('w').sum()
# Out:
#             Acess_Account
# 2023-01-01          14384
# 2023-01-08         100796
# 2023-01-15         100198
# 2023-01-22         100730
# 2023-01-29         100348
# 2023-02-05          82873

# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
dataframe=pd.read_csv(url)
data=dataframe.set_index(dataframe['NOC'])
sum=data.loc['FIN']
sum.head(50)
# Out:
#      Year                    City     Sport       Discipline  NOC  \
# NOC
# FIN  1924                Chamonix  Biathlon         Biathlon  FIN
# FIN  1924                Chamonix   Skating   Figure skating  FIN
# FIN  1924                Chamonix   Skating    Speed skating  FIN
# FIN  1924                Chamonix   Skating    Speed skating  FIN
# FIN  1924                Chamonix   Skating    Speed skating  FIN
# FIN  1924                Chamonix   Skating    Speed skating  FIN
# FIN  1924                Chamonix   Skating    Speed skating  FIN
# FIN  1924                Chamonix   Skating    Speed skating  FIN
# FIN  1924                Chamonix   Skating    Speed skating  FIN
# FIN  1924                Chamonix   Skating    Speed skating  FIN
# FIN  1924                Chamonix    Skiing  Cross Country S  FIN
# FIN  1928              St. Moritz   Skating    Speed skating  FIN
# FIN  1928              St. Moritz   Skating    Speed skating  FIN
# ...

# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
dataframe=pd.read_csv(url)
data=dataframe.set_index(dataframe['NOC'])
sum=data.loc['FIN']
sum.head(20)
sum['Medal'].value_counts() #Số huy chuong vàng bạc đồng của FIN
# Out:
# Silver    58
# Bronze    52
# Gold      41
# Name: Medal, dtype: int64

# %%
import pandas as pd
url='http://winterolympicsmedals.com/medals.csv'
dataframe=pd.read_csv(url)
data=dataframe.set_index(dataframe['NOC'])
sum=data.loc['FIN']
sum.head(20)
pair=dataframe[dataframe['Event']=='pairs'].head(20)
pair['Medal'].value_counts()
#Số huy chương thể lệ đôi của FIN
# Out:
# Gold      7
# Silver    7
# Bronze    6
# Name: Medal, dtype: int64

# %%
# !git config --global user.email "binhduc0402@gmail.com"
# !git config --global user.name "Nguyen Duc Binh"

# %%
#tìm tổng số huy chương của 1 nước
#tìm tổng số huy chương vàng, bạc trong cá nhân, đồng đội,
#tìm số huy chương tbtb

# %% [markdown]
# # New Section
